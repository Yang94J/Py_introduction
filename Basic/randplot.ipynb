# %% [markdown]
# # 1. 生成100对数据，画出散点图，并针对y数据画出分布

# %%
import matplotlib.pyplot as plt
import random
data = range(0,1000,1)
x = random.sample(data, 100)
y = random.sample(data, 100)
plt.scatter(x,y)
plt.show()
print(y)
plt.hist(y, 10, density=True)
# Out:
# [267, 966, 117, 114, 210, 211, 832, 378, 846, 554, 803, 911, 629, 590, 816, 265, 336, 275, 505, 842, 477, 471, 913, 385, 45, 985, 86, 30, 578, 146, 527, 102, 952, 849, 643, 549, 353, 737, 711, 548, 462, 214, 352, 555, 323, 877, 604, 920, 607, 120, 750, 304, 175, 673, 855, 923, 951, 908, 261, 369, 101, 546, 290, 603, 620, 934, 691, 863, 802, 621, 798, 655, 113, 149, 82, 443, 431, 785, 764, 539, 955, 585, 984, 725, 21, 423, 700, 55, 438, 319, 781, 7, 354, 370, 42, 87, 889, 50, 728, 71]
# (array([0.00132924, 0.00071575, 0.000818  , 0.00112474, 0.00071575,
#         0.00112474, 0.00102249, 0.00092025, 0.00112474, 0.00132924]),
#  array([  7. , 104.8, 202.6, 300.4, 398.2, 496. , 593.8, 691.6, 789.4,
#         887.2, 985. ]),
#  <a list of 10 Patch objects>)
